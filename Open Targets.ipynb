# %%
import sys
import subprocess

# implement pip as a subprocess:
packages = ['pandas','numpy','pyarrow']
for p in packages:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install',p])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/saad/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/saad/.local/lib/python3.10/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/saad/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/saad/.local/lib/python3.10/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/saad/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/saad/.local/lib/python3.10/site-packages (1.24.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /home/saad/.local/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/saad/.local/lib/python3.10/site-packages (from pyarrow) (1.24.1)

# %%
import os
import pandas as pd
import numpy as np
import io
import fnmatch
import tarfile
from ftplib import FTP,error_perm
from IPython.display import display

# %%
paths_to_df = [
 ('targets.feather','targets.tar.gz','pub/databases/opentargets/platform/21.11/output/etl/parquet/targets')
,('diseases.feather','diseases.tar.gz','pub/databases/opentargets/platform/21.11/output/etl/parquet/diseases')
,('evidence.feather','evidence.tar.gz','pub/databases/opentargets/platform/21.11/output/etl/parquet/evidence/sourceId=eva')
]

# %%
def load_datasets_with_fallback():
    try:
        for feather_path,parquet_path,ftp_path in paths_to_df:
            if os.path.isfile(feather_path):
                yield pd.read_feather(feather_path)
            elif os.path.isfile(parquet_path):
                with tarfile.open(parquet_path, "r:*") as tar:
                    df = pd.concat([pd.read_parquet(tar.extractfile(file)) for file in tar.getnames()])
                    df.reset_index().to_feather(feather_path,compression = 'lz4')
                    yield pd.read_feather(feather_path)
            else:
                ftp = FTP('ftp.ebi.ac.uk')
                ftp.login()
                ftp.cwd(path)
                files = [filename for filename in ftp.nlst() if fnmatch.fnmatch(filename, '*.parquet')]
                with tarfile.open(parquet_path, "w:gz") as fout:
                    for file_ in files:
                        buffer = io.BytesIO()
                        ftp.retrbinary('RETR ' + str(file_), buffer.write)
                        size = buffer.getbuffer().nbytes
                        print(f"Size of {file_} is: {size}")
                        tf = tarfile.TarInfo(file_)
                        tf.size = size
                        buffer.seek(0)
                        fout.addfile(tf,buffer)
                with tarfile.open(parquet_path, "r:*") as tar:
                    df = pd.concat([pd.read_parquet(tar.extractfile(file)) for file in tar.getnames()])
                    df.reset_index().to_feather(feather_path,compression = 'lz4')
                    yield pd.read_feather(feather_path)
    except error_perm as resp:
        if str(resp) == "550 No files found":
            print("No files in this directory")
        else:
            raise

# %%
targets_df,diseases_df,evidence_df = list(load_datasets_with_fallback())
display(targets_df)
display(diseases_df)
display(evidence_df)
# Out:
#        index               id   approvedSymbol               biotype  \
# 0          0  ENSG00000020219          CCT8L1P  processed_pseudogene
# 1          1  ENSG00000059588           TARBP1        protein_coding
# 2          2  ENSG00000070182             SPTB        protein_coding
# 3          3  ENSG00000070366             SMG6        protein_coding
# 4          4  ENSG00000072071           ADGRL1        protein_coding
# ...      ...              ...              ...                   ...
# 60631    282  ENSG00000287783  ENSG00000287783                lncRNA
# 60632    283  ENSG00000287887  ENSG00000287887                lncRNA
# 60633    284  ENSG00000287908  ENSG00000287908        protein_coding
# 60634    285  ENSG00000287915  ENSG00000287915                lncRNA
# 60635    286  ENSG00000288026  ENSG00000288026                lncRNA
#
#                                            transcriptIds  \
# 0                                      [ENST00000465400]
# 1      [ENST00000496673, ENST00000484454, ENST0000048...
# 2      [ENST00000553938, ENST00000389720, ENST0000055...
# 3      [ENST00000354901, ENST00000570756, ENST0000057...
# 4      [ENST00000361434, ENST00000589616, ENST0000059...
# ...                                                  ...
# 60631                 [ENST00000667965, ENST00000662579]
# 60632                                  [ENST00000662637]
# 60633                 [ENST00000477314, ENST00000474359]
# 60634                                  [ENST00000662300]
# 60635                                  [ENST00000667168]
#
#                                          genomicLocation   alternativeGenes  \
# 0      {'chromosome': '7', 'end': 152447150, 'start':...               None
# 1      {'chromosome': '1', 'end': 234479179, 'start':...               None
# 2      {'chromosome': '14', 'end': 64879907, 'start':...               None
# 3      {'chromosome': '17', 'end': 2303785, 'start': ...               None
# 4      {'chromosome': '19', 'end': 14206187, 'start':...  [ENSG00000288324]
# ...                                                  ...                ...
# 60631  {'chromosome': '5', 'end': 87774070, 'start': ...               None
# 60632  {'chromosome': '13', 'end': 24755201, 'start':...               None
# 60633  {'chromosome': '12', 'end': 57626125, 'start':...               None
# 60634  {'chromosome': '15', 'end': 60223272, 'start':...               None
# 60635  {'chromosome': '16', 'end': 48055099, 'start':...               None
#
#                                             approvedName  \
# 0      chaperonin containing TCP1 subunit 8 like 1, p...
# 1                      TAR (HIV-1) RNA binding protein 1
# 2                            spectrin beta, erythrocytic
# 3               SMG6 nonsense mediated mRNA decay factor
# 4                 adhesion G protein-coupled receptor L1
# ...                                                  ...
# 60631                                   novel transcript
# 60632                                   novel transcript
# 60633                                      novel protein
# 60634                                   novel transcript
# 60635                                   novel transcript
#
#                                                       go hallmarks  ...  \
# 0                                                   None      None  ...
# 1      [{'aspect': 'F', 'ecoId': 'ECO:0007669', 'evid...      None  ...
# 2      [{'aspect': 'P', 'ecoId': 'ECO:0007669', 'evid...      None  ...
# 3      [{'aspect': 'P', 'ecoId': 'ECO:0000314', 'evid...      None  ...
# 4      [{'aspect': 'F', 'ecoId': 'ECO:0000250', 'evid...      None  ...
# ...                                                  ...       ...  ...
# 60631                                               None      None  ...
# 60632                                               None      None  ...
# 60633                                               None      None  ...
# 60634                                               None      None  ...
# 60635                                               None      None  ...
#
#                                            obsoleteNames  \
# 0      [{'label': 'chaperonin containing TCP1, subuni...
# 1      [{'label': 'Tar (HIV-1) RNA binding protein 1'...
# 2                                                     []
# 3      [{'label': 'chromosome 17 open reading frame 3...
# 4         [{'label': 'latrophilin 1', 'source': 'HGNC'}]
# ...                                                  ...
# 60631                                                 []
# 60632                                                 []
# 60633                                                 []
# 60634                                                 []
# 60635                                                 []
#
#                                               constraint   tep  \
# 0                                                   None  None
# 1      [{'constraintType': 'syn', 'exp': 272.51000976...  None
# 2      [{'constraintType': 'syn', 'exp': 586.70001220...  None
# 3      [{'constraintType': 'syn', 'exp': 321.14001464...  None
# 4      [{'constraintType': 'syn', 'exp': 424.92999267...  None
# ...                                                  ...   ...
# 60631                                               None  None
# 60632                                               None  None
# 60633                                               None  None
# 60634                                               None  None
# 60635                                               None  None
#
#                                               proteinIds  \
# 0       [{'id': 'A6NM43', 'source': 'uniprot_obsolete'}]
# 1      [{'id': 'Q13395', 'source': 'uniprot_swissprot...
# 2      [{'id': 'P11277', 'source': 'uniprot_swissprot...
# 3      [{'id': 'Q86US8', 'source': 'uniprot_swissprot...
# 4      [{'id': 'O94910', 'source': 'uniprot_swissprot...
# ...                                                  ...
# 60631                                               None
# 60632                                               None
# 60633     [{'id': 'E9PIH7', 'source': 'uniprot_trembl'}]
# 60634                                               None
# 60635                                               None
#
#                                                  dbXrefs chemicalProbes  \
# 0      [{'id': '32153', 'source': 'HGNC'}, {'id': 'IP...           None
# 1      [{'id': '11568', 'source': 'HGNC'}, {'id': '2H...           None
# 2      [{'id': '11274', 'source': 'HGNC'}, {'id': '1S...           None
# 3      [{'id': '17809', 'source': 'HGNC'}, {'id': '2D...           None
# 4      [{'id': '20973', 'source': 'HGNC'}, {'id': 'IP...           None
# ...                                                  ...            ...
# 60631                                                 []           None
# 60632                                                 []           None
# 60633                                                 []           None
# 60634                                                 []           None
# 60635                                                 []           None
#
#                                               homologues  \
# 0                                                   None
# 1      [{'homologyType': 'other_paralog', 'isHighConf...
# 2      [{'homologyType': 'other_paralog', 'isHighConf...
# 3      [{'homologyType': 'ortholog_one2one', 'isHighC...
# 4      [{'homologyType': 'other_paralog', 'isHighConf...
# ...                                                  ...
# 60631                                               None
# 60632                                               None
# 60633  [{'homologyType': 'within_species_paralog', 'i...
# 60634                                               None
# 60635                                               None
#
#                                             tractability safetyLiabilities  \
# 0                                                   None              None
# 1      [{'id': 'Approved Drug', 'modality': 'SM', 'va...              None
# 2      [{'id': 'Approved Drug', 'modality': 'SM', 'va...              None
# 3      [{'id': 'Approved Drug', 'modality': 'SM', 'va...              None
# 4      [{'id': 'Approved Drug', 'modality': 'SM', 'va...              None
# ...                                                  ...               ...
# 60631                                               None              None
# 60632                                               None              None
# 60633                                               None              None
# 60634                                               None              None
# 60635                                               None              None
#
#                                                 pathways
# 0                                                   None
# 1                                                   None
# 2      [{'pathway': 'COPI-mediated anterograde transp...
# 3      [{'pathway': 'Nonsense Mediated Decay (NMD) en...
# 4                                                   None
# ...                                                  ...
# 60631                                               None
# 60632                                               None
# 60633                                               None
# 60634                                               None
# 60635                                               None
#
# [60636 rows x 27 columns]
#        index              id                                       code  \
# 0          0       DOID_7551   http://purl.obolibrary.org/obo/DOID_7551
# 1          1      HP_0000031  http://purl.obolibrary.org/obo/HP_0000031
# 2          2      HP_0000857  http://purl.obolibrary.org/obo/HP_0000857
# 3          3      HP_0001693  http://purl.obolibrary.org/obo/HP_0001693
# 4          4      HP_0001730  http://purl.obolibrary.org/obo/HP_0001730
# ...      ...             ...                                        ...
# 18701    243  Orphanet_93322   http://www.orpha.net/ORDO/Orphanet_93322
# 18702    244  Orphanet_93925   http://www.orpha.net/ORDO/Orphanet_93925
# 18703    245  Orphanet_98539   http://www.orpha.net/ORDO/Orphanet_98539
# 18704    246  Orphanet_98636   http://www.orpha.net/ORDO/Orphanet_98636
# 18705    247  Orphanet_99951   http://www.orpha.net/ORDO/Orphanet_99951
#
#                                                  dbXRefs  \
# 0      [COHD:433417, ICD9:098.89, MeSH:D006069, NCIt:...
# 1      [UMLS:C0014534, SNOMEDCT_US:31070006, MSH:D004...
# 2                                        [UMLS:C3278636]
# 3                 [UMLS:C0232180, SNOMEDCT_US:442119001]
# 4                                        [UMLS:C1842138]
# ...                                                  ...
# 18701  [MESH:C535563, ICD10:Q72.5, MONDO:0010144, OMI...
# 18702  [UMLS:C0431363, ICD10:Q04.2, MONDO:0019757, SC...
# 18703                                                 []
# 18704                                    [MONDO:0020220]
# 18705  [OMIM:605253, DOID:0110195, GARD:0006170, MeSH...
#
#                                              description  \
# 0      A primary bacterial infectious disease that is...
# 1        The presence of inflammation of the epididymis.
# 2                                                   None
# 3      Pattern of blood flow in the heart that deviat...
# 4              A progressive form of hearing impairment.
# ...                                                  ...
# 18701  Tibial hemimelia is a rare congenital anomaly ...
# 18702  Alobar holoprosencephaly is the most severe cl...
# 18703                                               None
# 18704                                               None
# 18705  Charcot-Marie-Tooth disease type 4E (CMT4E) is...
#
#                                                name directLocationIds  \
# 0                                         gonorrhea              None
# 1                                      Epididymitis              None
# 2      Neonatal insulin-dependent diabetes mellitus              None
# 3                                     Cardiac shunt              None
# 4                    Progressive hearing impairment              None
# ...                                             ...               ...
# 18701                              Tibial hemimelia              None
# 18702                      Alobar holoprosencephaly              None
# 18703              Early-onset ataxia with dementia              None
# 18704                    Corneoiridogoniodysgenesis              None
# 18705           Charcot-Marie-Tooth disease type 4E              None
#
#       obsoleteTerms                                parents   sko  \
# 0              None           [EFO_0003955, MONDO_0000314]  None
# 1              None               [HP_0012649, HP_0000022]  None
# 2              None  [EFO_0000400, HP_0001952, HP_0000818]  None
# 3              None                           [HP_0011028]  None
# 4              None                           [HP_0000364]  None
# ...             ...                                    ...   ...
# 18701          None                        [Orphanet_2130]  None
# 18702          None                        [Orphanet_2162]  None
# 18703          None                       [Orphanet_98538]  None
# 18704          None                       [Orphanet_98632]  None
# 18705          None        [MONDO_0033352, Orphanet_64749]  None
#
#                                                 synonyms  \
# 0      {'hasBroadSynonym': None, 'hasExactSynonym': [...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      {'hasBroadSynonym': None, 'hasExactSynonym': [...
# ...                                                  ...
# 18701  {'hasBroadSynonym': None, 'hasExactSynonym': [...
# 18702  {'hasBroadSynonym': None, 'hasExactSynonym': [...
# 18703                                               None
# 18704  {'hasBroadSynonym': None, 'hasExactSynonym': [...
# 18705  {'hasBroadSynonym': None, 'hasExactSynonym': [...
#
#                                                ancestors  \
# 0      [EFO_0000512, EFO_0009663, MONDO_0100336, OTAR...
# 1      [HP_0000022, HP_0000078, EFO_0000651, HP_00126...
# 2      [HP_0000818, HP_0000118, OTAR_0000020, HP_0011...
# 3      [EFO_0000651, HP_0011028, HP_0000118, HP_00110...
# 4      [HP_0000364, EFO_0000651, HP_0000598, HP_0000118]
# ...                                                  ...
# 18701  [EFO_0004260, Orphanet_404571, OTAR_0000006, O...
# 18702  [Orphanet_183763, MONDO_0002025, MONDO_0019042...
# 18703  [MONDO_0002025, Orphanet_183500, OTAR_0000018,...
# 18704  [OTAR_0000018, Orphanet_183557, Orphanet_98632...
# 18705  [Orphanet_98497, Orphanet_183500, OTAR_0000006...
#
#                                              descendants  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                           [HP_0012382]
# 4                                           [HP_0000408]
# ...                                                  ...
# 18701                 [Orphanet_295079, Orphanet_295077]
# 18702                                    [MONDO_0012322]
# 18703  [Orphanet_247815, EFO_0009016, Orphanet_284282...
# 18704    [Orphanet_98941, Orphanet_708, Orphanet_101033]
# 18705                                                 []
#
#                                  children  \
# 0                                      []
# 1                                      []
# 2                                      []
# 3                            [HP_0012382]
# 4                            [HP_0000408]
# ...                                   ...
# 18701  [Orphanet_295077, Orphanet_295079]
# 18702                     [MONDO_0012322]
# 18703                     [Orphanet_1172]
# 18704                      [Orphanet_708]
# 18705                                  []
#
#                                         therapeuticAreas indirectLocationIds  \
# 0      [MONDO_0100336, OTAR_0000017, EFO_0005741, EFO...                None
# 1                                          [EFO_0000651]                None
# 2      [OTAR_0000020, EFO_0000651, EFO_0001379, EFO_0...                None
# 3                                          [EFO_0000651]                None
# 4                                          [EFO_0000651]                None
# ...                                                  ...                 ...
# 18701                       [OTAR_0000006, OTAR_0000018]                None
# 18702  [MONDO_0002025, EFO_0000618, OTAR_0000018, EFO...                None
# 18703         [MONDO_0002025, OTAR_0000018, EFO_0000618]                None
# 18704                      [OTAR_0000018, MONDO_0024458]                None
# 18705          [OTAR_0000006, EFO_0000618, OTAR_0000018]                None
#
#                                                 ontology
# 0      {'isTherapeuticArea': False, 'leaf': True, 'so...
# 1      {'isTherapeuticArea': False, 'leaf': True, 'so...
# 2      {'isTherapeuticArea': False, 'leaf': True, 'so...
# 3      {'isTherapeuticArea': False, 'leaf': False, 's...
# 4      {'isTherapeuticArea': False, 'leaf': False, 's...
# ...                                                  ...
# 18701  {'isTherapeuticArea': False, 'leaf': False, 's...
# 18702  {'isTherapeuticArea': False, 'leaf': False, 's...
# 18703  {'isTherapeuticArea': False, 'leaf': False, 's...
# 18704  {'isTherapeuticArea': False, 'leaf': False, 's...
# 18705  {'isTherapeuticArea': False, 'leaf': True, 'so...
#
# [18706 rows x 17 columns]
#         index datasourceId         targetId alleleOrigins allelicRequirements  \
# 0           0          eva  ENSG00000168646    [germline]                None
# 1           1          eva  ENSG00000183873    [germline]                None
# 2           2          eva  ENSG00000101605    [germline]                None
# 3           3          eva  ENSG00000169247    [germline]                None
# 4           4          eva  ENSG00000096696    [germline]                None
# ...       ...          ...              ...           ...                 ...
# 210868   5543          eva  ENSG00000168646    [germline]                None
# 210869   5544          eva  ENSG00000169562    [germline]                None
# 210870   5545          eva  ENSG00000062822    [germline]                None
# 210871   5546          eva  ENSG00000155657    [germline]                None
# 210872   5547          eva  ENSG00000204264    [germline]                None
#
#         beta  betaConfidenceIntervalLower  betaConfidenceIntervalUpper  \
# 0        NaN                          NaN                          NaN
# 1        NaN                          NaN                          NaN
# 2        NaN                          NaN                          NaN
# 3        NaN                          NaN                          NaN
# 4        NaN                          NaN                          NaN
# ...      ...                          ...                          ...
# 210868   NaN                          NaN                          NaN
# 210869   NaN                          NaN                          NaN
# 210870   NaN                          NaN                          NaN
# 210871   NaN                          NaN                          NaN
# 210872   NaN                          NaN                          NaN
#
#        biologicalModelAllelicComposition biologicalModelGeneticBackground  \
# 0                                   None                             None
# 1                                   None                             None
# 2                                   None                             None
# 3                                   None                             None
# 4                                   None                             None
# ...                                  ...                              ...
# 210868                              None                             None
# 210869                              None                             None
# 210870                              None                             None
# 210871                              None                             None
# 210872                              None                             None
#
#         ... targetModulation textMiningSentences  urls  \
# 0       ...             None                None  None
# 1       ...             None                None  None
# 2       ...             None                None  None
# 3       ...             None                None  None
# 4       ...             None                None  None
# ...     ...              ...                 ...   ...
# 210868  ...             None                None  None
# 210869  ...             None                None  None
# 210870  ...             None                None  None
# 210871  ...             None                None  None
# 210872  ...             None                None  None
#
#        variantAminoacidDescriptions  variantFunctionalConsequenceId  \
# 0                              None                      SO_0001819
# 1                              None                      SO_0001583
# 2                              None                      SO_0001589
# 3                              None                      SO_0001624
# 4                              None                      SO_0001574
# ...                             ...                             ...
# 210868                         None                      SO_0001819
# 210869                         None                      SO_0001589
# 210870                         None                      SO_0001819
# 210871                         None                      SO_0001819
# 210872                         None                      SO_0001624
#
#                  variantId   variantRsId        diseaseId  \
# 0          17_65537821_C_T  rs1053887162  Orphanet_300576
# 1           3_38550706_T_C  rs1038605800     Orphanet_130
# 2       18_3129232_CTCTG_C          None      EFO_0000538
# 3          5_148998409_A_T   rs545169695      EFO_0004143
# 4            6_7559224_A_G          None     Orphanet_247
# ...                    ...           ...              ...
# 210868     17_65558462_G_A          None  Orphanet_300576
# 210869     X_71224504_GC_G  rs1602350003     Orphanet_166
# 210870     19_50402359_C_T   rs746475325  Orphanet_140162
# 210871     2_178729466_G_A          None     Orphanet_263
# 210872      6_32840843_G_A          None  Orphanet_324999
#
#                                               id score
# 0       000b404a55aab3d6e7df8d43501ec930a3f92fd8  0.02
# 1       0010135b87920c6d0c95690fcc5380217479fe6b  0.32
# 2       002d610963d28704f2b207b4b14c47f2b55df14b  0.32
# 3       0030b182518da8abfc29d349fe478bfb66903132  0.02
# 4       003bb0a89a48ab62d4f57b2c0b6f1a29f099b4a3  0.72
# ...                                          ...   ...
# 210868  ffdfa4b3c9a9212774a86a99f39beed20318d1a6  0.02
# 210869  ffe4c57006027b9016c07f390c505e9bf8c5ab5a  0.90
# 210870  ffe88b1f2bbe8aaebff80111bde247fefbf090a3  0.02
# 210871  ffeaf543ce77a973514d395d2df49e94de8ec95e  0.32
# 210872  fff395754e40f4f71bcd0209715dcca7e6ef7bad  0.32
#
# [210873 rows x 72 columns]

# %%
evidence_df = evidence_df[['targetId','diseaseId','score']]
c = ['targetId', 'diseaseId']
# trgt_disease_with_median = evidence_df.groupby(c)['score'].median()
trgt_disease_with_medain_top3   = evidence_df.groupby(c,as_index=False).agg(median = pd.NamedAgg(column='score', aggfunc='median'),
                                                      top3   = pd.NamedAgg(column='score', aggfunc= lambda x: (x.nlargest(3).tolist())
                                                                              ))

# %%
joined_targets_df = trgt_disease_with_medain_top3.merge(targets_df[['id','approvedSymbol']],left_on='targetId',right_on='id')

joined_targets_df.drop(['id'],axis=1,inplace=True)
joined_targets_df
# Out:
#               targetId        diseaseId  median                top3  \
# 0      ENSG00000000419       HP_0001249    0.00               [0.0]
# 1      ENSG00000000419     Orphanet_137    0.32   [0.92, 0.92, 0.9]
# 2      ENSG00000000971      EFO_0001365    0.32  [0.32, 0.32, 0.32]
# 3      ENSG00000000971      EFO_1001155    0.02  [0.92, 0.32, 0.32]
# 4      ENSG00000000971  Orphanet_200421    0.02  [0.02, 0.02, 0.02]
# ...                ...              ...     ...                 ...
# 12057  ENSG00000288702   Orphanet_79235    0.32              [0.32]
# 12058  ENSG00000288705      EFO_0005556    0.32    [0.9, 0.72, 0.5]
# 12059  ENSG00000288705    Orphanet_2312    0.32   [0.9, 0.32, 0.32]
# 12060  ENSG00000288705   Orphanet_79234    0.32   [0.9, 0.72, 0.32]
# 12061  ENSG00000288705   Orphanet_79235    0.90    [0.9, 0.9, 0.72]
#
#       approvedSymbol
# 0               DPM1
# 1               DPM1
# 2                CFH
# 3                CFH
# 4                CFH
# ...              ...
# 12057         UGT1A3
# 12058         UGT1A5
# 12059         UGT1A5
# 12060         UGT1A5
# 12061         UGT1A5
#
# [12062 rows x 5 columns]

# %%
joined_target_diesease_df = joined_targets_df.merge(diseases_df[['id','name']],left_on = 'diseaseId',right_on = 'id')
joined_target_diesease_df.drop(['id'],axis=1,inplace=True)
joined_target_diesease_df
# Out:
#               targetId       diseaseId  median          top3   approvedSymbol  \
# 0      ENSG00000000419      HP_0001249    0.00         [0.0]             DPM1
# 1      ENSG00000004848      HP_0001249    0.00         [0.0]              ARX
# 2      ENSG00000004961      HP_0001249    0.00         [0.0]             HCCS
# 3      ENSG00000005302      HP_0001249    0.72        [0.72]             MSL3
# 4      ENSG00000005339      HP_0001249    0.00    [0.0, 0.0]           CREBBP
# ...                ...             ...     ...           ...              ...
# 12057  ENSG00000284770   Orphanet_2333    0.72        [0.72]             TBCE
# 12058  ENSG00000285053   MONDO_0014968    0.52  [0.72, 0.32]             TBCE
# 12059  ENSG00000285053  Orphanet_93324    0.72        [0.72]             TBCE
# 12060  ENSG00000285708     EFO_0009908    0.72        [0.72]  ENSG00000285708
# 12061  ENSG00000288695   MONDO_0012991    0.90         [0.9]  ENSG00000288695
#
#                                                     name
# 0                                Intellectual disability
# 1                                Intellectual disability
# 2                                Intellectual disability
# 3                                Intellectual disability
# 4                                Intellectual disability
# ...                                                  ...
# 12057                              Kenny-Caffey syndrome
# 12058  encephalopathy, progressive, with amyotrophy a...
# 12059          Autosomal recessive Kenny-Caffey syndrome
# 12060                               glabellar hemangioma
# 12061                                   Kahrizi syndrome
#
# [12062 rows x 6 columns]

# %%
joined_target_diesease_df.sort_values(by=['median']).to_json('output.json',orient= 'records')

print('Result for part one is now stored as output.json')

# %%
target_disease_df = joined_target_diesease_df[['targetId','diseaseId']]

# %%
result = pd.merge(target_disease_df,target_disease_df, on='diseaseId',suffixes =['','_right'])

result = result[result.targetId != result.targetId_right]

c = ['targetId','targetId_right']

target_target_disease_count = result.groupby(c,as_index=False).count()
target_target_disease_count = target_target_disease_count[target_target_disease_count.diseaseId >= 2]

print('Number of target-target pairs which share a connection to at least two diseases:',len(target_target_disease_count.index))
# Out:
# Number of target-target pairs which share a connection to at least two diseases: 87286
